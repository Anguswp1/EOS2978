# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pyqg

year = 24*60*60*360.
m = pyqg.QGModel(tmax=10*year, twrite=10000, tavestart=5*year)
m.run()

q_upper = m.q[0] + m.Qy[0]*m.y
plt.contourf(m.x, m.y, q_upper, 12, cmap='RdBu_r')
plt.xlabel('x'); plt.ylabel('y'); plt.title('Upper Layer PV')
plt.colorbar();
# Out:
# INFO:  Logger initialized
# INFO: Step: 10000, Time: 7.20e+07, KE: 4.62e-04, CFL: 0.085
# INFO: Step: 20000, Time: 1.44e+08, KE: 4.86e-04, CFL: 0.100
# INFO: Step: 30000, Time: 2.16e+08, KE: 5.22e-04, CFL: 0.104
# INFO: Step: 40000, Time: 2.88e+08, KE: 4.72e-04, CFL: 0.092
