# %%
#=================================================================
# This first cell contains some necessary initialization commands.
#=================================================================
import sys
sys.path.append('/mnt/local/pyferret/lib/python3.6/site-packages')
import pyferret
import numpy as np
pyferret.addenv(FER_DIR='/mnt/local/pyferret', FER_DAT='/mnt/local/FerretDatasets')
pyferret.start(journal=False, quiet=True, unmapped=True)
# %load_ext ferretmagic

# %%
# %%ferret
# use /mnt/courses/eos2585/AVISO/SSH_ALL_avg.cdf
# shade ADT; go fland
# contour /over /color=1 /levels=(-1.5,1.5,0.25) ADT
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">! Enter_GO fland
# ! Exit_GO
# </pre>
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# sh d
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> /mnt/courses/eos2585/AVISO/SSH_ALL_avg.cdf  (default)
#  name     title                             I         J         K         L
#  CRS                                       ...       ...       ...       ...
#  ADT      Absolute Dynamic Topography      1:1440    1:720     ...       1:1
#
# </pre>

# %%
# %%ferret
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/my10yearrun/repo/output/ocean/CLIO3m.001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/my10yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !shade /d=2 /levels=(-inf)(-5,-3,0.1)(inf) ssh[l=1],tlon,tlat; go fland
# !shade /d=2 fcor[l=1],tlon,tlat; go fland
# shade /levels=(5.0,20.0,50.0)zmix[l=1]; go fland
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade /levels=(5.0,20.0,50.0)zmix[l=1]; go fland
# **ERROR: variable unknown or not in data set: ADT </pre>

# %%
# %%ferret
# sh d
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> /mnt/courses/eos2585/AVISO/SSH_ALL_avg.cdf
#  name     title                             I         J         K         L
#  CRS                                       ...       ...       ...       ...
#  ADT      Absolute Dynamic Topography      1:1440    1:720     ...       1:1
#
#     2> /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/example/repo/output/ocean/CLIO3m.001506_001.nc
#  name     title                             I         J         K         L
#  TLON     longitude                        1:120     1:65      ...       ...
#  TLON_BOUNDS
#           longitude edges                  1:120     1:65      1:4       ...
#  TLONP    longitude bounds                 1:121     1:66      ...       ...
#  TLAT     latitude                         1:120     1:65      ...       ...
#  TLAT_BOUNDS
#           latitude edges                   1:120     1:65      1:4       ...
#  TLATP    latitude bounds                  1:121     1:66      ...       ...
#  ULON     longitude                        1:120     1:65      ...       ...
#  ULON_BOUNDS
#           longitude edges                  1:120     1:65      1:4       ...
#  ULONP    longitude bounds                 1:121     1:66      ...       ...
#  ULAT     latitude                         1:120     1:65      ...       ...
#  ULAT_BOUNDS
#           latitude edges                   1:120     1:65      1:4       ...
#  ULATP    latitude bounds                  1:121     1:66      ...       ...
#  ANGLE    clockwise rotation of x-axis     1:120     1:65      ...       ...
#  DXS1     zonal length of grid box sides   1:120     1:65      ...       ...
#  DXS2     meridional length of grid box s  1:120     1:65      ...       ...
#  DXC1     zonal width at grid box centres  1:120     1:65      ...       ...
#  DXC2     meridional width at grid box ce  1:120     1:65      ...       ...
#  AREA     surface area of tracer grid box  1:120     1:65      ...       ...
#  TMASK    horizontal tracer grid mask      1:120     1:65      ...       ...
#  UMASK    horizontal momentum grid mask    1:120     1:65      ...       ...
#  H        bathymetry on tracer gridpoints  1:120     1:65      ...       ...
#  FCOR     Coriolis parameter on momentum   1:120     1:65      ...       ...
#  SST      averaged SST                     1:120     1:65      ...       1:24
#  SSS      averaged sea surface salinity    1:120     1:65      ...       1:24
#  ZCNV     averaged depth of convection     1:120     1:65      ...       1:24
#  ALBQ     averaged lead fraction           1:120     1:65      ...       1:24
#
#     3> /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/example/repo/output/ocean/CLIO3a.001506_001.nc  (default)
#  name     title                             I         J         K         L
#  TLON     longitude                        1:120     1:65      ...       ...
#  TLON_BOUNDS
#           longitude edges                  1:120     1:65      1:4       ...
#  TLONP    longitude bounds                 1:121     1:66      ...       ...
#  TLAT     latitude                         1:120     1:65      ...       ...
#  TLAT_BOUNDS
#           latitude edges                   1:120     1:65      1:4       ...
#  TLATP    latitude bounds                  1:121     1:66      ...       ...
#  ULON     longitude                        1:120     1:65      ...       ...
#  ULON_BOUNDS
#           longitude edges                  1:120     1:65      1:4       ...
#  ULONP    longitude bounds                 1:121     1:66      ...       ...
#  ULAT     latitude                         1:120     1:65      ...       ...
#  ULAT_BOUNDS
#           latitude edges                   1:120     1:65      1:4       ...
#  ULATP    latitude bounds                  1:121     1:66      ...       ...
#  ANGLE    clockwise rotation of x-axis     1:120     1:65      ...       ...
#  DXS1     zonal length of grid box sides   1:120     1:65      ...       ...
#  DXS2     meridional length of grid box s  1:120     1:65      ...       ...
#  DXC1     zonal width at grid box centres  1:120     1:65      ...       ...
#  DXC2     meridional width at grid box ce  1:120     1:65      ...       ...
#  AREA     surface area of tracer grid box  1:120     1:65      ...       ...
#  TMASK    horizontal tracer grid mask      1:120     1:65      ...       ...
#  UMASK    horizontal momentum grid mask    1:120     1:65      ...       ...
#  H        bathymetry on tracer gridpoints  1:120     1:65      ...       ...
#  FCOR     Coriolis parameter on momentum   1:120     1:65      ...       ...
#  TEMP     averaged potential temperature   1:120     1:65      1:20      1:2
#  SALT     averaged salinity                1:120     1:65      1:20      1:2
#  U        averaged zonal velocity compone  1:120     1:65      1:20      1:2
#  V        averaged meridional velocity co  1:120     1:65      1:20      1:2
#  W        averaged vertical velocity comp  1:120     1:65      1:21      1:2
#  UBAR     averaged zonal barotropic momen  1:120     1:65      ...       1:2
#  VBAR     averaged meridional barotropic   1:120     1:65      ...       1:2
#  SSH      averaged sea surface height      1:120     1:65      ...       1:2
#  SST      averaged SST                     1:120     1:65      ...       1:2
#  SSS      averaged sea surface salinity    1:120     1:65      ...       1:2
#  SHFLX    averaged surface heat flux       1:120     1:65      ...       1:2
#  SFFLX    averaged surface freshwater flu  1:120     1:65      ...       1:2
#  ZMIX     averaged depth of ocean surface  1:120     1:65      ...       1:2
#  ZCNV     averaged depth of convection     1:120     1:65      ...       1:2
#  MSL      averaged G-M slope               1:120     1:65      ...       1:2
#  HICE     averaged ice thickness           1:120     1:65      ...       1:2
#  HICP     averaged ice production          1:120     1:65      ...       1:2
#  ALBQ     averaged lead fraction           1:120     1:65      ...       1:2
#  HSN      averaged snow thickness          1:120     1:65      ...       1:2
#  SNOW     averaged snow precipitation      1:120     1:65      ...       1:2
#  TICE     averaged ice temperature         1:120     1:65      ...       1:2
#  FB       averaged heat flux at ice base   1:120     1:65      ...       1:2
#  UICE     averaged zonal ice velocity      1:120     1:65      ...       1:2
#  VICE     averaged meridional ice velocit  1:120     1:65      ...       1:2
#  WSX      averaged zonal wind stress       1:120     1:65      ...       1:2
#  WSY      averaged meridional wind stress  1:120     1:65      ...       1:2
#  MOC      meridional overturning streamfu  1:4       1:57      1:22      1:2
#  MHT      meridional heat transport        1:4       1:57      ...       1:2
#  MST      meridional salt transport        1:4       1:57      ...       1:2
#  AGE      averaged water age               1:120     1:65      1:20      1:2
#
# </pre>

# %%
# %%ferret
# shade /d=2 /levels=(-inf)(-5,-3,0.1)(inf) ssh[l=1],tlon,tlat; go fland
# shade /d=2 ssh[l=1],tlon,tlat; go fland
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade /d=2 /levels=(-inf)(-5,-3,0.1)(inf) ssh[l=1],tlon,tlat; go fland
# **ERROR: variable unknown or not in data set: SSH[L=1] </pre>

# %%
# %%ferret
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/example/repo/output/ocean/CLIO3m.001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/example/repo/output/ocean/CLIO3a.001506_001.nc
# shade ssh[d=3,l=2]
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# !ncdump -h /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/example/repo/output/ocean/CLIO3a.001506_001.nc
# Out:
# netcdf CLIO3a.001506_001 {
# dimensions:
# 	ptlon = 120 ;
# 	pulon = 120 ;
# 	ptlat = 65 ;
# 	pulat = 65 ;
# 	tdepth = 20 ;
# 	wdepth = 21 ;
# 	wedges = 22 ;
# 	corners = 4 ;
# 	sflat = 57 ;
# 	sfdepth = 22 ;
# 	sfedges = 23 ;
# 	basidx = 4 ;
# 	ptlonp = 121 ;
# 	pulonp = 121 ;
# 	ptlatp = 66 ;
# 	pulatp = 66 ;
# 	time = UNLIMITED ; // (2 currently)
# variables:
# 	double ptlon(ptlon) ;
# 		ptlon:units = "degrees_east" ;
# 		ptlon:long_name = "pseudo tracer grid longitude" ;
# 		ptlon:modulo = "m" ;
# 		ptlon:topology = "circular" ;
# 	double pulon(pulon) ;
# 		pulon:units = "degrees_east" ;
# 		pulon:long_name = "pseudo momentum grid longitude" ;
# 		pulon:modulo = "m" ;
# 		pulon:topology = "circular" ;
# 	double ptlat(ptlat) ;
# 		ptlat:units = "degrees_north" ;
# 		ptlat:long_name = "pseudo tracer grid latitude" ;
# 	double pulat(pulat) ;
# 		pulat:units = "degrees_north" ;
# 		pulat:long_name = "pseudo momentum grid latitude" ;
# 	double tdepth(tdepth) ;
# 		tdepth:units = "meters" ;
# 		tdepth:long_name = "depth of tracer points" ;
# 		tdepth:point_spacing = "uneven" ;
# 		tdepth:positive = "up" ;
# 		tdepth:edges = "wdepth" ;
# 	double wdepth(wdepth) ;
# 		wdepth:units = "meters" ;
# 		wdepth:long_name = "depth of vertical momentum points" ;
# 		wdepth:point_spacing = "uneven" ;
# 		wdepth:positive = "up" ;
# 		wdepth:edges = "wedges" ;
# 	double wedges(wedges) ;
# 		wedges:units = "meters" ;
# 		wedges:long_name = "edges of vertical momentum boxes" ;
# 		wedges:point_spacing = "uneven" ;
# 		wedges:positive = "up" ;
# 	double sflat(sflat) ;
# 		sflat:units = "degrees_north" ;
# 		sflat:long_name = "latitude" ;
# 	double sfdepth(sfdepth) ;
# 		sfdepth:units = "meters" ;
# 		sfdepth:long_name = "streamfunction depth" ;
# 		sfdepth:point_spacing = "uneven" ;
# 		sfdepth:positive = "up" ;
# 		sfdepth:edges = "sfedges" ;
# 	double sfedges(sfedges) ;
# 		sfedges:units = "meters" ;
# 		sfedges:long_name = "edges of streamfunction depths" ;
# 		sfedges:point_spacing = "uneven" ;
# 		sfedges:positive = "up" ;
# 	int basidx(basidx) ;
# 		basidx:long_name = "longitude" ;
# 	double time(time) ;
# 		time:calendar = "360_day" ;
# 		time:units = "years since 0000-00-00 00:00:00" ;
# 		time:delta_t = "0001-00-00 00:00:00" ;
# 		time:avg_period = "0001-00-00 00:00:00" ;
# 	double tlon(ptlat, ptlon) ;
# 		tlon:missing_value = -1.e+32 ;
# 		tlon:units = "degrees_east" ;
# 		tlon:long_name = "longitude" ;
# 		tlon:point_spacing = "uneven" ;
# 		tlon:bounds = "tlon_bounds" ;
# 	double tlon_bounds(corners, ptlat, ptlon) ;
# 		tlon_bounds:missing_value = -1.e+32 ;
# 		tlon_bounds:units = "degrees_east" ;
# 		tlon_bounds:long_name = "longitude edges" ;
# 		tlon_bounds:point_spacing = "uneven" ;
# 	double tlonp(ptlatp, ptlonp) ;
# 		tlonp:missing_value = -1.e+32 ;
# 		tlonp:units = "degrees_east" ;
# 		tlonp:long_name = "longitude bounds" ;
# 		tlonp:point_spacing = "uneven" ;
# 	double tlat(ptlat, ptlon) ;
# 		tlat:missing_value = -1.e+32 ;
# 		tlat:units = "degrees_north" ;
# 		tlat:long_name = "latitude" ;
# 		tlat:point_spacing = "uneven" ;
# 		tlat:bounds = "tlat_bounds" ;
# 	double tlat_bounds(corners, ptlat, ptlon) ;
# 		tlat_bounds:missing_value = -1.e+32 ;
# 		tlat_bounds:units = "degrees_north" ;
# 		tlat_bounds:long_name = "latitude edges" ;
# 		tlat_bounds:point_spacing = "uneven" ;
# 	double tlatp(ptlatp, ptlonp) ;
# 		tlatp:missing_value = -1.e+32 ;
# 		tlatp:units = "degrees_north" ;
# 		tlatp:long_name = "latitude bounds" ;
# 		tlatp:point_spacing = "uneven" ;
# 	double ulon(pulat, pulon) ;
# 		ulon:missing_value = -1.e+32 ;
# 		ulon:units = "degrees_east" ;
# 		ulon:long_name = "longitude" ;
# 		ulon:point_spacing = "uneven" ;
# 		ulon:bounds = "ulon_bounds" ;
# 	double ulon_bounds(corners, pulat, pulon) ;
# 		ulon_bounds:missing_value = -1.e+32 ;
# 		ulon_bounds:units = "degrees_east" ;
# 		ulon_bounds:long_name = "longitude edges" ;
# 		ulon_bounds:point_spacing = "uneven" ;
# 	double ulonp(pulatp, pulonp) ;
# 		ulonp:missing_value = -1.e+32 ;
# 		ulonp:units = "degrees_east" ;
# 		ulonp:long_name = "longitude bounds" ;
# 		ulonp:point_spacing = "uneven" ;
# 	double ulat(pulat, pulon) ;
# 		ulat:missing_value = -1.e+32 ;
# 		ulat:units = "degrees_north" ;
# 		ulat:long_name = "latitude" ;
# 		ulat:point_spacing = "uneven" ;
# 		ulat:bounds = "ulat_bounds" ;
# 	double ulat_bounds(corners, pulat, pulon) ;
# 		ulat_bounds:missing_value = -1.e+32 ;
# 		ulat_bounds:units = "degrees_north" ;
# 		ulat_bounds:long_name = "latitude edges" ;
# 		ulat_bounds:point_spacing = "uneven" ;
# 	double ulatp(pulatp, pulonp) ;
# 		ulatp:missing_value = -1.e+32 ;
# 		ulatp:units = "degrees_north" ;
# 		ulatp:long_name = "latitude bounds" ;
# 		ulatp:point_spacing = "uneven" ;
# 	double angle(pulat, pulon) ;
# 		angle:missing_value = -1.e+32 ;
# 		angle:units = "radians" ;
# 		angle:long_name = "clockwise rotation of x-axis" ;
# 		angle:point_spacing = "uneven" ;
# 		angle:coordinates = "ulon ulat" ;
# 	double dxs1(ptlat, ptlon) ;
# 		dxs1:missing_value = -1.e+32 ;
# 		dxs1:units = "meters" ;
# 		dxs1:long_name = "zonal length of grid box sides" ;
# 		dxs1:point_spacing = "uneven" ;
# 		dxs1:coordinates = "tlon tlat" ;
# 	double dxs2(ptlat, ptlon) ;
# 		dxs2:missing_value = -1.e+32 ;
# 		dxs2:units = "meters" ;
# 		dxs2:long_name = "meridional length of grid box sides" ;
# 		dxs2:point_spacing = "uneven" ;
# 		dxs2:coordinates = "tlon tlat" ;
# 	double dxc1(ptlat, ptlon) ;
# 		dxc1:missing_value = -1.e+32 ;
# 		dxc1:units = "meters" ;
# 		dxc1:long_name = "zonal width at grid box centres" ;
# 		dxc1:point_spacing = "uneven" ;
# 		dxc1:coordinates = "tlon tlat" ;
# 	double dxc2(ptlat, ptlon) ;
# 		dxc2:missing_value = -1.e+32 ;
# 		dxc2:units = "meters" ;
# 		dxc2:long_name = "meridional width at grid box centres" ;
# 		dxc2:point_spacing = "uneven" ;
# 		dxc2:coordinates = "tlon tlat" ;
# 	double area(ptlat, ptlon) ;
# 		area:missing_value = -1.e+32 ;
# 		area:units = "meters**2" ;
# 		area:long_name = "surface area of tracer grid box" ;
# 		area:point_spacing = "uneven" ;
# 		area:coordinates = "tlon tlat" ;
# 	int tmask(ptlat, ptlon) ;
# 		tmask:missing_value = 99 ;
# 		tmask:units = "none" ;
# 		tmask:long_name = "horizontal tracer grid mask" ;
# 		tmask:coordinates = "tlon tlat" ;
# 	int umask(pulat, pulon) ;
# 		umask:missing_value = 99 ;
# 		umask:units = "none" ;
# 		umask:long_name = "horizontal momentum grid mask" ;
# 		umask:coordinates = "ulon ulat" ;
# 	double h(ptlat, ptlon) ;
# 		h:missing_value = -1.e+32 ;
# 		h:units = "meters" ;
# 		h:long_name = "bathymetry on tracer gridpoints" ;
# 		h:coordinates = "tlon tlat" ;
# 	double fcor(pulat, pulon) ;
# 		fcor:missing_value = -1.e+32 ;
# 		fcor:units = "1/seconds" ;
# 		fcor:long_name = "Coriolis parameter on momentum grid" ;
# 		fcor:coordinates = "ulon ulat" ;
# 	double temp(time, tdepth, ptlat, ptlon) ;
# 		temp:units = "Celsius" ;
# 		temp:long_name = "averaged potential temperature" ;
# 		temp:coordinates = "tlon tlat tdepth time" ;
# 		temp:missing_value = -1.e+32 ;
# 	double salt(time, tdepth, ptlat, ptlon) ;
# 		salt:units = "PSU" ;
# 		salt:long_name = "averaged salinity" ;
# 		salt:coordinates = "tlon tlat tdepth time" ;
# 		salt:missing_value = -1.e+32 ;
# 	double u(time, tdepth, pulat, pulon) ;
# 		u:units = "m.s-1" ;
# 		u:long_name = "averaged zonal velocity component" ;
# 		u:coordinates = "ulon ulat tdepth time" ;
# 		u:missing_value = -1.e+32 ;
# 	double v(time, tdepth, pulat, pulon) ;
# 		v:units = "m.s-1" ;
# 		v:long_name = "averaged meridional velocity component" ;
# 		v:coordinates = "ulon ulat tdepth time" ;
# 		v:missing_value = -1.e+32 ;
# 	double w(time, wdepth, ptlat, ptlon) ;
# 		w:units = "m.day-1" ;
# 		w:long_name = "averaged vertical velocity component" ;
# 		w:coordinates = "tlon tlat wdepth time" ;
# 		w:missing_value = -1.e+32 ;
# 	double ubar(time, pulat, pulon) ;
# 		ubar:units = "m.s-1" ;
# 		ubar:long_name = "averaged zonal barotropic momentum" ;
# 		ubar:coordinates = "ulon ulat time" ;
# 		ubar:missing_value = -1.e+32 ;
# 	double vbar(time, pulat, pulon) ;
# 		vbar:units = "m.s-1" ;
# 		vbar:long_name = "averaged meridional barotropic momentum" ;
# 		vbar:coordinates = "ulon ulat time" ;
# 		vbar:missing_value = -1.e+32 ;
# 	double ssh(time, ptlat, ptlon) ;
# 		ssh:units = "m" ;
# 		ssh:long_name = "averaged sea surface height" ;
# 		ssh:coordinates = "tlon tlat time" ;
# 		ssh:missing_value = -1.e+32 ;
# 	double sst(time, ptlat, ptlon) ;
# 		sst:units = "Celsius" ;
# 		sst:long_name = "averaged SST" ;
# 		sst:coordinates = "tlon tlat time" ;
# 		sst:missing_value = -1.e+32 ;
# 	double sss(time, ptlat, ptlon) ;
# 		sss:units = "PSU" ;
# 		sss:long_name = "averaged sea surface salinity" ;
# 		sss:coordinates = "tlon tlat time" ;
# 		sss:missing_value = -1.e+32 ;
# 	double shflx(time, ptlat, ptlon) ;
# 		shflx:units = "W.m-2" ;
# 		shflx:long_name = "averaged surface heat flux" ;
# 		shflx:coordinates = "tlon tlat time" ;
# 		shflx:missing_value = -1.e+32 ;
# 	double sfflx(time, ptlat, ptlon) ;
# 		sfflx:units = "m.y-1" ;
# 		sfflx:long_name = "averaged surface freshwater flux" ;
# 		sfflx:coordinates = "tlon tlat time" ;
# 		sfflx:missing_value = -1.e+32 ;
# 	double zmix(time, ptlat, ptlon) ;
# 		zmix:units = "m" ;
# 		zmix:long_name = "averaged depth of ocean surface mixed layer" ;
# 		zmix:coordinates = "tlon tlat time" ;
# 		zmix:missing_value = -1.e+32 ;
# 	double zcnv(time, ptlat, ptlon) ;
# 		zcnv:units = "m" ;
# 		zcnv:long_name = "averaged depth of convection" ;
# 		zcnv:coordinates = "tlon tlat time" ;
# 		zcnv:missing_value = -1.e+32 ;
# 	double msl(time, ptlat, ptlon) ;
# 		msl:units = "1" ;
# 		msl:long_name = "averaged G-M slope" ;
# 		msl:coordinates = "tlon tlat time" ;
# 		msl:missing_value = -1.e+32 ;
# 	double hice(time, ptlat, ptlon) ;
# 		hice:units = "m" ;
# 		hice:long_name = "averaged ice thickness" ;
# 		hice:coordinates = "tlon tlat time" ;
# 		hice:missing_value = -1.e+32 ;
# 	double hicp(time, ptlat, ptlon) ;
# 		hicp:units = "m" ;
# 		hicp:long_name = "averaged ice production" ;
# 		hicp:coordinates = "tlon tlat time" ;
# 		hicp:missing_value = -1.e+32 ;
# 	double albq(time, ptlat, ptlon) ;
# 		albq:units = "1" ;
# 		albq:long_name = "averaged lead fraction" ;
# 		albq:coordinates = "tlon tlat time" ;
# 		albq:missing_value = -1.e+32 ;
# 	double hsn(time, ptlat, ptlon) ;
# 		hsn:units = "m" ;
# 		hsn:long_name = "averaged snow thickness" ;
# 		hsn:coordinates = "tlon tlat time" ;
# 		hsn:missing_value = -1.e+32 ;
# 	double snow(time, ptlat, ptlon) ;
# 		snow:units = "m" ;
# 		snow:long_name = "averaged snow precipitation" ;
# 		snow:coordinates = "tlon tlat time" ;
# 		snow:missing_value = -1.e+32 ;
# 	double tice(time, ptlat, ptlon) ;
# 		tice:units = "Celsius" ;
# 		tice:long_name = "averaged ice temperature" ;
# 		tice:coordinates = "tlon tlat time" ;
# 		tice:missing_value = -1.e+32 ;
# 	double fb(time, ptlat, ptlon) ;
# 		fb:units = "W.m-2" ;
# 		fb:long_name = "averaged heat flux at ice base" ;
# 		fb:coordinates = "tlon tlat time" ;
# 		fb:missing_value = -1.e+32 ;
# 	double uice(time, pulat, pulon) ;
# 		uice:units = "m.s-1" ;
# 		uice:long_name = "averaged zonal ice velocity" ;
# 		uice:coordinates = "ulon ulat time" ;
# 		uice:missing_value = -1.e+32 ;
# 	double vice(time, pulat, pulon) ;
# 		vice:units = "m.s-1" ;
# 		vice:long_name = "averaged meridional ice velocity" ;
# 		vice:coordinates = "ulon ulat time" ;
# 		vice:missing_value = -1.e+32 ;
# 	double wsx(time, pulat, pulon) ;
# 		wsx:units = "N.m-2" ;
# 		wsx:long_name = "averaged zonal wind stress" ;
# 		wsx:coordinates = "ulon ulat time" ;
# 		wsx:missing_value = -1.e+32 ;
# 	double wsy(time, pulat, pulon) ;
# 		wsy:units = "N.m-2" ;
# 		wsy:long_name = "averaged meridional wind stress" ;
# 		wsy:coordinates = "ulon ulat time" ;
# 		wsy:missing_value = -1.e+32 ;
# 	double moc(time, sfdepth, sflat, basidx) ;
# 		moc:units = "Sv" ;
# 		moc:long_name = "meridional overturning streamfunction" ;
# 		moc:comment = "i-index: 1=global 2=Indian 3=Pacific 4=Atlantic&Arctic ocean" ;
# 		moc:missing_value = -1.e+32 ;
# 	double mht(time, sflat, basidx) ;
# 		mht:units = "Pw" ;
# 		mht:long_name = "meridional heat transport" ;
# 		mht:comment = "i-index: 1=global 2=Indian 3=Pacific 4=Atlantic&Arctic ocean" ;
# 		mht:missing_value = -1.e+32 ;
# 	double mst(time, sflat, basidx) ;
# 		mst:units = "Sv*PSU" ;
# 		mst:long_name = "meridional salt transport" ;
# 		mst:comment = "i-index: 1=global 2=Indian 3=Pacific 4=Atlantic&Arctic ocean" ;
# 		mst:missing_value = -1.e+32 ;
# 	double age(time, tdepth, ptlat, ptlon) ;
# 		age:units = "Year" ;
# 		age:long_name = "averaged water age" ;
# 		age:coordinates = "tlon tlat tdepth time" ;
# 		age:missing_value = -1.e+32 ;
#
# // global attributes:
# 		:title = "LOVECLIM1.2 model output prepared for PMIP3 experiment" ;
# 		:institution = "TECLIM - Georges Lemaitre Centre for Earth and Climate Research, Louvain-la-Neuve, Belgium" ;
# 		:source = "LOVECLIM1.2 (2010) - atmosphere: ECBILT(32x64xL3,T21L3) - ocean: CLIO(122x65xL20,3x3,L20)" ;
# 		:contact = "thierry.fichefet@uclouvain.be, hugues.goosse@uclouvain.be, marie-france.loutre@uclouvain.be" ;
# 		:project_id = "iClips" ;
# 		:table_id = "Table Omon (7 April 2004)" ;
# 		:experiment_id = "piControl" ;
# 		:realization = "1" ;
# 		:cmor_version = "1.1f" ;
# 		:Conventions = "CF-1.0" ;
# 		:history = "Output from PMIP3/output" ;
# 		:reences = "Model described by Goosse et al. (Geosci. Model Dev., 2010, 576-591). Also see http://www.climate.be" ;
# 		:comment = "Test drive" ;
# 		:experiment = "pre-industrial control" ;
# 		:institute_id = "LOVECLIM" ;
# 		:model_id = "LOVECLIM1.2" ;
# 		:forcing = "Pre-industrial GHG, insolation" ;
# 		:parent_experiment_id = "piControl" ;
# 		:branch_time = "001506" ;
# 		:initialization_method = "1" ;
# 		:physics_version = "1" ;
# 		:tracking_id = "417e3c51-c0e2-4ca9-b99e-cfb5d09beb67" ;
# 		:product = "output" ;
# 		:frequency = "yr" ;
# 		:creation_date = "2021-04-14T21:28:37Z" ;
# 		:modeling_realm = "ocean" ;
# }
