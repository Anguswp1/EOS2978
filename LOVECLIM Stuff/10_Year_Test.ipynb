# %%
#=================================================================
# This first cell contains some necessary initialization commands.
#=================================================================
import sys
sys.path.append('/mnt/local/pyferret/lib/python3.6/site-packages')
import pyferret
import numpy as np
pyferret.addenv(FER_DIR='/mnt/local/pyferret', FER_DAT='/mnt/local/FerretDatasets')
pyferret.start(journal=False, quiet=True, unmapped=True)
# %load_ext ferretmagic

# %%
# %%ferret
# !use /mnt/courses/eos2585/AVISO/SSH_ALL_avg.cdf
# shade ADT; go fland
# contour /over /color=1 /levels=(-1.5,1.5,0.25) ADT
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade ADT; go fland
# **ERROR: variable unknown or not in data set: ADT </pre>

# %%
# %%ferret
# sh d
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
# </pre>

# %%
# %%ferret
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/my10yearrun/repo/output/ocean/CLIO3m.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/my10yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/control100yearrun/repo/output/ocean/CLIO3m.001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/control100yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg_2x_100yearrun/repo/output/ocean/CLIO3m.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg_2x_100yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !shade /d=2 /levels=(-inf)(-5,-3,0.1)(inf) ssh[l=1],tlon,tlat; go fland
# !shade /d=2 fcor[l=1],tlon,tlat; go fland
# !shade /levels=(5.0,20.0,50.0)zmix[l=1]; go fland

# %%
# %%ferret
# sh d
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/control100yearrun/repo/output/atmos/atmmmyl001506_001.nc
#  name     title                             I         J         K         L         M         N
#  LON_BOUNDS
#                                            1:64      ...       ...       ...       1:2       ...
#  LAT_BOUNDS
#                                            ...       1:32      ...       ...       1:2       ...
#  TIME_BOUNDS
#                                            ...       ...       ...       1:1200    1:2       ...
#  Q        Specific Humidity                1:64      1:32      ...       1:1200    ...       ...
#  TS       Surface Temperature              1:64      1:32      ...       1:1200    ...       ...
#  BM       Bottom Moisture                  1:64      1:32      ...       1:1200    ...       ...
# ...

# %%
# %%ferret
# !shade /d=2 /levels=(-inf)(-5,-3,0.1)(inf) ssh[l=1],tlon,tlat; go fland
# !shade / ssh[d=3,l=2],tlon,tlat; go fland

# %%
# %%ferret
# !this is a control 100 year run
# shade/title="100 Year Control Run " /levels=(-inf)(-2,32,0.5)(inf) TEMP[d=5,k=20,l=@MAX],tlon,tlat; go fland
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade/title="100 Year Control Run " /levels=(-inf)(-2,32,0.5)(inf) TEMP[d=5,k=20,l=@MAX],tlon,tlat; go fland
# **ERROR: unknown data set: D=5 </pre>

# %%
# %%ferret
# !this is a 100 year run with greenhouse gases doubling over the second 50 years
# shade/title="100 Year Double GHG Run" /levels=(-inf)(-2,32,0.5)(inf) TEMP[d=6,l=@MAX,k=20],tlon,tlat; go fland
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade/title="100 Year Double GHG Run" /levels=(-inf)(-2,32,0.5)(inf) TEMP[d=6,l=@MAX,k=20],tlon,tlat; go fland
# **ERROR: unknown data set: D=6 </pre>

# %%
# %%ferret
# MAX(TEMP[d=6,l=100,k=20]);
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? MAX(TEMP[d=6,l=100,k=20]);
# **ERROR: command syntax: MAX(TEMP[d=6,l=100,k=20]) </pre>

# %%
# %%ferret
# shade/title="100 Year Double GHG Run" /levels=(-inf)(2,240,1)(inf) ZCNV[d=4,l=100],tlon,tlat; go fland
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade/title="100 Year Double GHG Run" /levels=(-inf)(2,240,1)(inf) ZCNV[d=4,l=100],tlon,tlat; go fland
# **ERROR: unknown data set: D=4 </pre>

# %%
# %%ferret
# shade/title="100 Year Double GHG Run" /levels=(-inf)(2,240,1)(inf) ZCNV[d=6,l=100],tlon,tlat; go fland
# Out:
# <pre style="background-color:#F79F81; border-radius: 4px 4px 4px 4px; font-size: smaller">yes? shade/title="100 Year Double GHG Run" /levels=(-inf)(2,240,1)(inf) ZCNV[d=6,l=100],tlon,tlat; go fland
# **ERROR: unknown data set: D=6 </pre>

# %%
# %%ferret
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/control100yearrun/repo/output/atmos/atmmmyl001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg_2x_100yearrun/repo/output/atmos/atmmmyl001506_001.nc

# %%
# %%ferret
# sh d
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/control100yearrun/repo/output/atmos/atmmmyl001506_001.nc
#  name     title                             I         J         K         L         M         N
#  LON_BOUNDS
#                                            1:64      ...       ...       ...       1:2       ...
#  LAT_BOUNDS
#                                            ...       1:32      ...       ...       1:2       ...
#  TIME_BOUNDS
#                                            ...       ...       ...       1:1200    1:2       ...
#  Q        Specific Humidity                1:64      1:32      ...       1:1200    ...       ...
#  TS       Surface Temperature              1:64      1:32      ...       1:1200    ...       ...
#  BM       Bottom Moisture                  1:64      1:32      ...       1:1200    ...       ...
# ...

# %%
# %%ferret
# shade PP[l=1200]-PP[l=1]
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# plot ts[x=@AVE,y=@AVE,d=2]
# plot /over/color=2 ts[x=@AVE,y=@AVE,l=@SBX:12,d=2]
# plot /over/color=3 ts[x=@AVE,y=@AVE,l=@SBX:12,d=1]
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# shade /levels=(-inf)(34.0,36.0,0.2)(inf) salt[d=4,i=104,l=1]
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>
