# %%
#=================================================================
# This first cell contains some necessary initialization commands.
#=================================================================
import sys
sys.path.append('/mnt/local/pyferret/lib/python3.6/site-packages')
import pyferret
import numpy as np
pyferret.addenv(FER_DIR='/mnt/local/pyferret', FER_DAT='/mnt/local/FerretDatasets')
pyferret.start(journal=False, quiet=True, unmapped=True)
# %load_ext ferretmagic

# %%
# %%ferret
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/cooling_10_yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/my10yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg2x_10_yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg3x_10_yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg4x10yearrun/repo/output/ocean/CLIO3a.001506_001.nc
# !use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg2x_SRM_10_yearrun/repo/output/ocean/CLIO3a.001506_001.nc
#
#
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/cooling_10_yearrun/repo/output/atmos/atmmmyl001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/my10yearrun/repo/output/atmos/atmmmyl001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg2x_10_yearrun/repo/output/atmos/atmmmyl001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg3x_10_yearrun/repo/output/atmos/atmmmyl001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg4x10yearrun/repo/output/atmos/atmmmyl001506_001.nc
# use /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/ghg2x_SRM_10_yearrun/repo/output/atmos/atmmmyl001506_001.nc

# %%
# %%ferret
# sh d
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> /mnt/research/sgary/aparton/data/storage/LOVECLIM1.3/cooling_10_yearrun/repo/output/atmos/atmmmyl001506_001.nc
#  name     title                             I         J         K         L         M         N
#  LON_BOUNDS
#                                            1:64      ...       ...       ...       1:2       ...
#  LAT_BOUNDS
#                                            ...       1:32      ...       ...       1:2       ...
#  TIME_BOUNDS
#                                            ...       ...       ...       1:120     1:2       ...
#  Q        Specific Humidity                1:64      1:32      ...       1:120     ...       ...
#  TS       Surface Temperature              1:64      1:32      ...       1:120     ...       ...
#  BM       Bottom Moisture                  1:64      1:32      ...       1:120     ...       ...
# ...

# %%
# %%ferret
# plot /title= "control" /vlim= 14.85:17/color=3 ts[d=2,x=@AVE,y=@AVE,l=@SBX:12]-273
# plot /title= "control" /over /color=3 ts[d=2,x=@AVE,y=@AVE,l=@SBX:12]-273
# plot /title="warming 2x" /over /color=4 ts[d=3,x=@AVE,y=@AVE,l=@SBX:12]-273
# plot /title="SRM +Warming 2x" /over /color=5 ts[d=6,x=@AVE,y=@AVE,l=@SBX:12]-273
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# !plot /title="cooling"  /color=3 ts[d=3,x=@AVE,y=@AVE,l=@SBX:12]-273
#  plot ts[d=3,x=@AVE,y=@AVE,l=@SBX:12]-ts[d=2,x=@AVE,y=@AVE,l=@SBX:12]
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>
